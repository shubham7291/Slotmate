# %%
! pip install torch gym numpy pandas fastapi uvicorn
# Out:
# Requirement already satisfied: torch in c:\users\hp\anaconda3\lib\site-packages (1.12.1)
# Collecting gym
#   Downloading gym-0.26.2.tar.gz (721 kB)
#      -------------------------------------- 721.7/721.7 kB 1.3 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy in c:\users\hp\anaconda3\lib\site-packages (1.23.5)
# Requirement already satisfied: pandas in c:\users\hp\anaconda3\lib\site-packages (2.2.3)
# Collecting fastapi
#   Downloading fastapi-0.115.6-py3-none-any.whl (94 kB)
#      ---------------------------------------- 94.8/94.8 kB 1.8 MB/s eta 0:00:00
# Collecting uvicorn
#   Downloading uvicorn-0.32.1-py3-none-any.whl (63 kB)
#      ---------------------------------------- 63.8/63.8 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: typing_extensions in c:\users\hp\anaconda3\lib\site-packages (from torch) (4.4.0)
# Collecting gym_notices>=0.0.4
#   Downloading gym_notices-0.0.8-py3-none-any.whl (3.0 kB)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\hp\anaconda3\lib\site-packages (from gym) (2.0.0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\anaconda3\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\appdata\roaming\python\python310\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas) (2022.7)
# Collecting pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4
#   Downloading pydantic-2.10.3-py3-none-any.whl (456 kB)
#      ------------------------------------ 457.0/457.0 kB 921.1 kB/s eta 0:00:00
# Collecting typing_extensions
#   Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Collecting starlette<0.42.0,>=0.40.0
#   Downloading starlette-0.41.3-py3-none-any.whl (73 kB)
#      -------------------------------------- 73.2/73.2 kB 670.1 kB/s eta 0:00:00
# Collecting h11>=0.8
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Requirement already satisfied: click>=7.0 in c:\users\hp\anaconda3\lib\site-packages (from uvicorn) (8.0.4)
# Requirement already satisfied: colorama in c:\users\hp\appdata\roaming\python\python310\site-packages (from click>=7.0->uvicorn) (0.4.5)
# Collecting annotated-types>=0.6.0
#   Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting pydantic-core==2.27.1
#   Downloading pydantic_core-2.27.1-cp310-none-win_amd64.whl (2.0 MB)
#      ---------------------------------------- 2.0/2.0 MB 223.6 kB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: anyio<5,>=3.4.0 in c:\users\hp\anaconda3\lib\site-packages (from starlette<0.42.0,>=0.40.0->fastapi) (3.5.0)
# Requirement already satisfied: idna>=2.8 in c:\users\hp\anaconda3\lib\site-packages (from anyio<5,>=3.4.0->starlette<0.42.0,>=0.40.0->fastapi) (3.4)
# Requirement already satisfied: sniffio>=1.1 in c:\users\hp\anaconda3\lib\site-packages (from anyio<5,>=3.4.0->starlette<0.42.0,>=0.40.0->fastapi) (1.2.0)
# Building wheels for collected packages: gym
#   Building wheel for gym (pyproject.toml): started
#   Building wheel for gym (pyproject.toml): finished with status 'done'
#   Created wheel for gym: filename=gym-0.26.2-py3-none-any.whl size=827636 sha256=c5b6e9a2f13d091d59472fde68f1ab4ab025f439a618d27edf6a121191b77a95
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\ae\5f\67\64914473eb34e9ba89dbc7eefe7e9be8f6673fbc6f0273b29f
# Successfully built gym
# Installing collected packages: gym_notices, typing_extensions, h11, gym, annotated-types, uvicorn, starlette, pydantic-core, pydantic, fastapi
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.4.0
#     Uninstalling typing_extensions-4.4.0:
#       Successfully uninstalled typing_extensions-4.4.0
# Successfully installed annotated-types-0.7.0 fastapi-0.115.6 gym-0.26.2 gym_notices-0.0.8 h11-0.14.0 pydantic-2.10.3 pydantic-core-2.27.1 starlette-0.41.3 typing_extensions-4.12.2 uvicorn-0.32.1

# %%
import numpy as np
import gym
from gym import spaces

class DeliveryEnv(gym.Env):
    def __init__(self, user_data, sender_data):
        super(DeliveryEnv, self).__init__()
        # Historical user and sender data
        self.user_data = user_data
        self.sender_data = sender_data
        
        # Define state space (example: day, holiday, historical success rate)
        self.observation_space = spaces.Box(low=0, high=1, shape=(6,), dtype=np.float32)
        
        # Define action space (e.g., 6 delivery time slots)
        self.action_space = spaces.Discrete(6)
        
        # Internal state
        self.current_state = None
    
    def reset(self):
        """Reset environment to initial state."""
        self.current_state = np.random.rand(6)  # Simulated initial state
        return self.current_state
    
    def step(self, action):
        """Execute an action and return the new state, reward, and done."""
        # Simulate delivery outcome based on action
        delivery_success = np.random.choice([1, 0], p=[0.8, 0.2])  # Simulated success rate
        reward = 1 if delivery_success else -1  # Positive reward for success
        
        # Update state (simulated)
        self.current_state = np.random.rand(6)
        done = False  # Episodes are continuous in this example
        
        return self.current_state, reward, done, {}

# %%
import torch
import torch.nn as nn
import torch.optim as optim

class DQNAgent(nn.Module):
    def __init__(self, state_size, action_size):
        super(DQNAgent, self).__init__()
        self.fc1 = nn.Linear(state_size, 128)
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, action_size)
    
    def forward(self, state):
        x = torch.relu(self.fc1(state))
        x = torch.relu(self.fc2(x))
        return self.fc3(x)

class RLModel:
    def __init__(self, state_size, action_size):
        self.model = DQNAgent(state_size, action_size)
        self.optimizer = optim.Adam(self.model.parameters(), lr=0.001)
        self.criterion = nn.MSELoss()
        self.memory = []  # Replay buffer
    
    def act(self, state, epsilon=0.1):
        """Epsilon-greedy policy."""
        if np.random.rand() < epsilon:
            return np.random.randint(0, 6)  # Random action
        with torch.no_grad():
            state_tensor = torch.FloatTensor(state).unsqueeze(0)
            return torch.argmax(self.model(state_tensor)).item()
    
    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))
        if len(self.memory) > 1000:
            self.memory.pop(0)
    
    def replay(self, batch_size=32):
        if len(self.memory) < batch_size:
            return
        batch = np.random.choice(len(self.memory), batch_size, replace=False)
        batch = [self.memory[idx] for idx in batch]

        states, actions, rewards, next_states, dones = zip(*batch)
        
        states = torch.FloatTensor(states)
        actions = torch.LongTensor(actions)
        rewards = torch.FloatTensor(rewards)
        next_states = torch.FloatTensor(next_states)
        dones = torch.FloatTensor(dones)
        
        q_values = self.model(states).gather(1, actions.unsqueeze(1)).squeeze(1)
        next_q_values = self.model(next_states).max(1)[0]
        expected_q_values = rewards + (0.99 * next_q_values * (1 - dones))
        
        loss = self.criterion(q_values, expected_q_values.detach())
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

# %%
# Simulated data
user_data = {'history': []}  # Placeholder
sender_data = {'history': []}  # Placeholder

env = DeliveryEnv(user_data, sender_data)
agent = RLModel(state_size=6, action_size=6)

episodes = 1000
for episode in range(episodes):
    state = env.reset()
    total_reward = 0
    
    for _ in range(50):  # Maximum steps per episode
        action = agent.act(state)
        next_state, reward, done, _ = env.step(action)
        agent.remember(state, action, reward, next_state, done)
        agent.replay()
        
        state = next_state
        total_reward += reward
        
        if done:
            break
    
    print(f"Episode {episode + 1}: Total Reward: {total_reward}")
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_16640\1928964303.py:45: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  C:\b\abs_bao0hdcrdh\croot\pytorch_1675190257512\work\torch\csrc\utils\tensor_new.cpp:204.)
#   states = torch.FloatTensor(states)
# Episode 1: Total Reward: 36
# Episode 2: Total Reward: 28
# Episode 3: Total Reward: 36
# Episode 4: Total Reward: 30
# Episode 5: Total Reward: 24
# Episode 6: Total Reward: 32
# Episode 7: Total Reward: 30
# Episode 8: Total Reward: 26
# Episode 9: Total Reward: 36
# Episode 10: Total Reward: 26
# Episode 11: Total Reward: 28
# Episode 12: Total Reward: 34
# Episode 13: Total Reward: 26
# Episode 14: Total Reward: 30
# Episode 15: Total Reward: 24
# Episode 16: Total Reward: 32
# Episode 17: Total Reward: 30
# Episode 18: Total Reward: 16
# Episode 19: Total Reward: 34
# Episode 20: Total Reward: 28
# Episode 21: Total Reward: 18
# Episode 22: Total Reward: 22
# Episode 23: Total Reward: 30
# Episode 24: Total Reward: 26
# Episode 25: Total Reward: 38
# Episode 26: Total Reward: 28
# Episode 27: Total Reward: 32
# Episode 28: Total Reward: 22
# Episode 29: Total Reward: 38
# Episode 30: Total Reward: 34
# Episode 31: Total Reward: 34
# Episode 32: Total Reward: 36
# Episode 33: Total Reward: 34
# Episode 34: Total Reward: 30
# Episode 35: Total Reward: 18
# Episode 36: Total Reward: 30
# Episode 37: Total Reward: 24
# Episode 38: Total Reward: 32
# Episode 39: Total Reward: 30
# Episode 40: Total Reward: 22
# Episode 41: Total Reward: 32
# Episode 42: Total Reward: 28
# Episode 43: Total Reward: 34
# Episode 44: Total Reward: 36
# Episode 45: Total Reward: 38
# Episode 46: Total Reward: 28
# Episode 47: Total Reward: 30
# Episode 48: Total Reward: 36
# Episode 49: Total Reward: 10
# Episode 50: Total Reward: 34
# Episode 51: Total Reward: 28
# Episode 52: Total Reward: 36
# Episode 53: Total Reward: 28
# Episode 54: Total Reward: 32
# Episode 55: Total Reward: 30
# Episode 56: Total Reward: 34
# Episode 57: Total Reward: 20
# Episode 58: Total Reward: 26
# Episode 59: Total Reward: 30
# Episode 60: Total Reward: 24
# Episode 61: Total Reward: 32
# Episode 62: Total Reward: 36
# Episode 63: Total Reward: 24
# Episode 64: Total Reward: 42
# Episode 65: Total Reward: 24
# Episode 66: Total Reward: 32
# Episode 67: Total Reward: 26
# Episode 68: Total Reward: 24
# Episode 69: Total Reward: 30
# Episode 70: Total Reward: 32
# Episode 71: Total Reward: 36
# Episode 72: Total Reward: 28
# Episode 73: Total Reward: 28
# Episode 74: Total Reward: 28
# Episode 75: Total Reward: 26
# Episode 76: Total Reward: 38
# Episode 77: Total Reward: 24
# Episode 78: Total Reward: 34
# Episode 79: Total Reward: 36
# Episode 80: Total Reward: 20
# Episode 81: Total Reward: 30
# Episode 82: Total Reward: 32
# Episode 83: Total Reward: 36
# Episode 84: Total Reward: 26
# Episode 85: Total Reward: 30
# Episode 86: Total Reward: 24
# Episode 87: Total Reward: 30
# Episode 88: Total Reward: 34
# Episode 89: Total Reward: 30
# Episode 90: Total Reward: 34
# Episode 91: Total Reward: 28
# Episode 92: Total Reward: 32
# Episode 93: Total Reward: 24
# Episode 94: Total Reward: 38
# Episode 95: Total Reward: 22
# Episode 96: Total Reward: 32
# Episode 97: Total Reward: 32
# Episode 98: Total Reward: 20
# Episode 99: Total Reward: 34
# Episode 100: Total Reward: 22
# Episode 101: Total Reward: 34
# Episode 102: Total Reward: 24
# Episode 103: Total Reward: 36
# Episode 104: Total Reward: 22
# Episode 105: Total Reward: 38
# Episode 106: Total Reward: 34
# Episode 107: Total Reward: 34
# Episode 108: Total Reward: 30
# Episode 109: Total Reward: 34
# Episode 110: Total Reward: 26
# Episode 111: Total Reward: 32
# Episode 112: Total Reward: 32
# Episode 113: Total Reward: 22
# Episode 114: Total Reward: 30
# Episode 115: Total Reward: 22
# Episode 116: Total Reward: 26
# Episode 117: Total Reward: 30
# Episode 118: Total Reward: 34
# Episode 119: Total Reward: 30
# Episode 120: Total Reward: 38
# Episode 121: Total Reward: 28
# Episode 122: Total Reward: 30
# Episode 123: Total Reward: 26
# Episode 124: Total Reward: 36
# Episode 125: Total Reward: 28
# Episode 126: Total Reward: 34
# Episode 127: Total Reward: 34
# Episode 128: Total Reward: 40
# Episode 129: Total Reward: 18
# Episode 130: Total Reward: 28
# Episode 131: Total Reward: 32
# Episode 132: Total Reward: 30
# Episode 133: Total Reward: 32
# Episode 134: Total Reward: 30
# Episode 135: Total Reward: 30
# Episode 136: Total Reward: 34
# Episode 137: Total Reward: 32
# Episode 138: Total Reward: 28
# Episode 139: Total Reward: 20
# Episode 140: Total Reward: 22
# Episode 141: Total Reward: 26
# Episode 142: Total Reward: 28
# Episode 143: Total Reward: 36
# Episode 144: Total Reward: 30
# Episode 145: Total Reward: 34
# Episode 146: Total Reward: 30
# Episode 147: Total Reward: 26
# Episode 148: Total Reward: 34
# Episode 149: Total Reward: 30
# Episode 150: Total Reward: 28
# Episode 151: Total Reward: 30
# Episode 152: Total Reward: 26
# Episode 153: Total Reward: 34
# Episode 154: Total Reward: 32
# Episode 155: Total Reward: 32
# Episode 156: Total Reward: 38
# Episode 157: Total Reward: 28
# Episode 158: Total Reward: 26
# Episode 159: Total Reward: 24
# Episode 160: Total Reward: 30
# Episode 161: Total Reward: 26
# Episode 162: Total Reward: 28
# Episode 163: Total Reward: 32
# Episode 164: Total Reward: 30
# Episode 165: Total Reward: 30
# Episode 166: Total Reward: 32
# Episode 167: Total Reward: 28
# Episode 168: Total Reward: 20
# Episode 169: Total Reward: 28
# Episode 170: Total Reward: 20
# Episode 171: Total Reward: 34
# Episode 172: Total Reward: 28
# Episode 173: Total Reward: 30
# Episode 174: Total Reward: 36
# Episode 175: Total Reward: 28
# Episode 176: Total Reward: 32
# Episode 177: Total Reward: 22
# Episode 178: Total Reward: 30
# Episode 179: Total Reward: 20
# Episode 180: Total Reward: 40
# Episode 181: Total Reward: 24
# Episode 182: Total Reward: 40
# Episode 183: Total Reward: 34
# Episode 184: Total Reward: 28
# Episode 185: Total Reward: 30
# Episode 186: Total Reward: 32
# Episode 187: Total Reward: 18
# Episode 188: Total Reward: 36
# Episode 189: Total Reward: 36
# Episode 190: Total Reward: 24
# Episode 191: Total Reward: 30
# Episode 192: Total Reward: 28
# Episode 193: Total Reward: 22
# Episode 194: Total Reward: 26
# Episode 195: Total Reward: 30
# Episode 196: Total Reward: 28
# Episode 197: Total Reward: 34
# Episode 198: Total Reward: 34
# Episode 199: Total Reward: 30
# Episode 200: Total Reward: 24
# Episode 201: Total Reward: 28
# Episode 202: Total Reward: 26
# Episode 203: Total Reward: 32
# Episode 204: Total Reward: 36
# Episode 205: Total Reward: 32
# Episode 206: Total Reward: 40
# Episode 207: Total Reward: 36
# Episode 208: Total Reward: 34
# Episode 209: Total Reward: 28
# Episode 210: Total Reward: 22
# Episode 211: Total Reward: 34
# Episode 212: Total Reward: 32
# Episode 213: Total Reward: 30
# Episode 214: Total Reward: 28
# Episode 215: Total Reward: 32
# Episode 216: Total Reward: 26
# Episode 217: Total Reward: 32
# Episode 218: Total Reward: 38
# Episode 219: Total Reward: 30
# Episode 220: Total Reward: 34
# Episode 221: Total Reward: 28
# Episode 222: Total Reward: 34
# Episode 223: Total Reward: 32
# Episode 224: Total Reward: 42
# Episode 225: Total Reward: 32
# Episode 226: Total Reward: 28
# Episode 227: Total Reward: 32
# Episode 228: Total Reward: 40
# Episode 229: Total Reward: 40
# Episode 230: Total Reward: 30
# Episode 231: Total Reward: 24
# Episode 232: Total Reward: 28
# Episode 233: Total Reward: 38
# Episode 234: Total Reward: 34
# Episode 235: Total Reward: 28
# Episode 236: Total Reward: 22
# Episode 237: Total Reward: 20
# Episode 238: Total Reward: 26
# Episode 239: Total Reward: 32
# Episode 240: Total Reward: 36
# Episode 241: Total Reward: 34
# Episode 242: Total Reward: 30
# Episode 243: Total Reward: 34
# Episode 244: Total Reward: 34
# Episode 245: Total Reward: 30
# Episode 246: Total Reward: 26
# Episode 247: Total Reward: 28
# Episode 248: Total Reward: 40
# Episode 249: Total Reward: 28
# Episode 250: Total Reward: 18
# Episode 251: Total Reward: 34
# Episode 252: Total Reward: 38
# Episode 253: Total Reward: 28
# Episode 254: Total Reward: 36
# Episode 255: Total Reward: 38
# Episode 256: Total Reward: 30
# Episode 257: Total Reward: 26
# Episode 258: Total Reward: 28
# Episode 259: Total Reward: 32
# Episode 260: Total Reward: 26
# Episode 261: Total Reward: 24
# Episode 262: Total Reward: 28
# Episode 263: Total Reward: 14
# Episode 264: Total Reward: 40
# Episode 265: Total Reward: 40
# Episode 266: Total Reward: 30
# Episode 267: Total Reward: 38
# Episode 268: Total Reward: 32
# Episode 269: Total Reward: 18
# Episode 270: Total Reward: 20
# Episode 271: Total Reward: 40
# Episode 272: Total Reward: 30
# Episode 273: Total Reward: 26
# Episode 274: Total Reward: 26
# Episode 275: Total Reward: 20
# Episode 276: Total Reward: 34
# Episode 277: Total Reward: 24
# Episode 278: Total Reward: 28
# Episode 279: Total Reward: 32
# Episode 280: Total Reward: 38
# Episode 281: Total Reward: 36
# Episode 282: Total Reward: 26
# Episode 283: Total Reward: 34
# Episode 284: Total Reward: 26
# Episode 285: Total Reward: 32
# Episode 286: Total Reward: 32
# Episode 287: Total Reward: 38
# Episode 288: Total Reward: 36
# Episode 289: Total Reward: 32
# Episode 290: Total Reward: 44
# Episode 291: Total Reward: 32
# Episode 292: Total Reward: 30
# Episode 293: Total Reward: 30
# Episode 294: Total Reward: 42
# Episode 295: Total Reward: 32
# Episode 296: Total Reward: 28
# Episode 297: Total Reward: 42
# Episode 298: Total Reward: 26
# Episode 299: Total Reward: 32
# Episode 300: Total Reward: 36
# Episode 301: Total Reward: 40
# Episode 302: Total Reward: 40
# Episode 303: Total Reward: 20
# Episode 304: Total Reward: 30
# Episode 305: Total Reward: 28
# Episode 306: Total Reward: 30
# Episode 307: Total Reward: 32
# Episode 308: Total Reward: 36
# Episode 309: Total Reward: 34
# Episode 310: Total Reward: 30
# Episode 311: Total Reward: 28
# Episode 312: Total Reward: 22
# Episode 313: Total Reward: 30
# Episode 314: Total Reward: 30
# Episode 315: Total Reward: 32
# Episode 316: Total Reward: 30
# Episode 317: Total Reward: 30
# Episode 318: Total Reward: 24
# Episode 319: Total Reward: 32
# Episode 320: Total Reward: 32
# Episode 321: Total Reward: 28
# Episode 322: Total Reward: 30
# Episode 323: Total Reward: 38
# Episode 324: Total Reward: 34
# Episode 325: Total Reward: 36
# Episode 326: Total Reward: 34
# Episode 327: Total Reward: 30
# Episode 328: Total Reward: 30
# Episode 329: Total Reward: 36
# Episode 330: Total Reward: 34
# Episode 331: Total Reward: 26
# Episode 332: Total Reward: 28
# Episode 333: Total Reward: 26
# Episode 334: Total Reward: 28
# Episode 335: Total Reward: 38
# Episode 336: Total Reward: 36
# Episode 337: Total Reward: 36
# Episode 338: Total Reward: 32
# Episode 339: Total Reward: 26
# Episode 340: Total Reward: 28
# Episode 341: Total Reward: 36
# Episode 342: Total Reward: 32
# Episode 343: Total Reward: 36
# Episode 344: Total Reward: 28
# Episode 345: Total Reward: 34
# Episode 346: Total Reward: 32
# Episode 347: Total Reward: 28
# Episode 348: Total Reward: 28
# Episode 349: Total Reward: 36
# Episode 350: Total Reward: 26
# Episode 351: Total Reward: 26
# Episode 352: Total Reward: 30
# Episode 353: Total Reward: 22
# Episode 354: Total Reward: 32
# Episode 355: Total Reward: 28
# Episode 356: Total Reward: 26
# Episode 357: Total Reward: 22
# Episode 358: Total Reward: 28
# Episode 359: Total Reward: 30
# Episode 360: Total Reward: 24
# Episode 361: Total Reward: 16
# Episode 362: Total Reward: 30
# Episode 363: Total Reward: 40
# Episode 364: Total Reward: 28
# Episode 365: Total Reward: 26
# Episode 366: Total Reward: 26
# Episode 367: Total Reward: 26
# Episode 368: Total Reward: 34
# Episode 369: Total Reward: 24
# Episode 370: Total Reward: 28
# Episode 371: Total Reward: 22
# Episode 372: Total Reward: 26
# Episode 373: Total Reward: 24
# Episode 374: Total Reward: 32
# Episode 375: Total Reward: 24
# Episode 376: Total Reward: 34
# Episode 377: Total Reward: 38
# Episode 378: Total Reward: 28
# Episode 379: Total Reward: 26
# Episode 380: Total Reward: 32
# Episode 381: Total Reward: 24
# Episode 382: Total Reward: 28
# Episode 383: Total Reward: 26
# Episode 384: Total Reward: 30
# Episode 385: Total Reward: 38
# Episode 386: Total Reward: 34
# Episode 387: Total Reward: 30
# Episode 388: Total Reward: 30
# Episode 389: Total Reward: 36
# Episode 390: Total Reward: 30
# Episode 391: Total Reward: 20
# Episode 392: Total Reward: 28
# Episode 393: Total Reward: 30
# Episode 394: Total Reward: 16
# Episode 395: Total Reward: 36
# Episode 396: Total Reward: 30
# Episode 397: Total Reward: 20
# Episode 398: Total Reward: 30
# Episode 399: Total Reward: 22
# Episode 400: Total Reward: 28
# Episode 401: Total Reward: 36
# Episode 402: Total Reward: 20
# Episode 403: Total Reward: 22
# Episode 404: Total Reward: 22
# Episode 405: Total Reward: 34
# Episode 406: Total Reward: 34
# Episode 407: Total Reward: 26
# Episode 408: Total Reward: 28
# Episode 409: Total Reward: 30
# Episode 410: Total Reward: 28
# Episode 411: Total Reward: 32
# Episode 412: Total Reward: 24
# Episode 413: Total Reward: 38
# Episode 414: Total Reward: 30
# Episode 415: Total Reward: 36
# Episode 416: Total Reward: 32
# Episode 417: Total Reward: 24
# Episode 418: Total Reward: 30
# Episode 419: Total Reward: 14
# Episode 420: Total Reward: 28
# Episode 421: Total Reward: 28
# Episode 422: Total Reward: 18
# Episode 423: Total Reward: 26
# Episode 424: Total Reward: 36
# Episode 425: Total Reward: 32
# Episode 426: Total Reward: 36
# Episode 427: Total Reward: 22
# Episode 428: Total Reward: 26
# Episode 429: Total Reward: 24
# Episode 430: Total Reward: 34
# Episode 431: Total Reward: 36
# Episode 432: Total Reward: 36
# Episode 433: Total Reward: 30
# Episode 434: Total Reward: 38
# Episode 435: Total Reward: 40
# Episode 436: Total Reward: 30
# Episode 437: Total Reward: 34
# Episode 438: Total Reward: 26
# Episode 439: Total Reward: 32
# Episode 440: Total Reward: 16
# Episode 441: Total Reward: 32
# Episode 442: Total Reward: 28
# Episode 443: Total Reward: 26
# Episode 444: Total Reward: 18
# Episode 445: Total Reward: 30
# Episode 446: Total Reward: 32
# Episode 447: Total Reward: 32
# Episode 448: Total Reward: 36
# Episode 449: Total Reward: 22
# Episode 450: Total Reward: 28
# Episode 451: Total Reward: 34
# Episode 452: Total Reward: 34
# Episode 453: Total Reward: 34
# Episode 454: Total Reward: 30
# Episode 455: Total Reward: 26
# Episode 456: Total Reward: 30
# Episode 457: Total Reward: 30
# Episode 458: Total Reward: 26
# Episode 459: Total Reward: 28
# Episode 460: Total Reward: 34
# Episode 461: Total Reward: 20
# Episode 462: Total Reward: 30
# Episode 463: Total Reward: 34
# Episode 464: Total Reward: 34
# Episode 465: Total Reward: 30
# Episode 466: Total Reward: 24
# Episode 467: Total Reward: 32
# Episode 468: Total Reward: 30
# Episode 469: Total Reward: 36
# Episode 470: Total Reward: 36
# Episode 471: Total Reward: 28
# Episode 472: Total Reward: 28
# Episode 473: Total Reward: 28
# Episode 474: Total Reward: 42
# Episode 475: Total Reward: 36
# Episode 476: Total Reward: 34
# Episode 477: Total Reward: 38
# Episode 478: Total Reward: 22
# Episode 479: Total Reward: 40
# Episode 480: Total Reward: 28
# Episode 481: Total Reward: 26
# Episode 482: Total Reward: 26
# Episode 483: Total Reward: 32
# Episode 484: Total Reward: 26
# Episode 485: Total Reward: 28
# Episode 486: Total Reward: 28
# Episode 487: Total Reward: 38
# Episode 488: Total Reward: 26
# Episode 489: Total Reward: 32
# Episode 490: Total Reward: 16
# Episode 491: Total Reward: 26
# Episode 492: Total Reward: 28
# Episode 493: Total Reward: 36
# Episode 494: Total Reward: 30
# Episode 495: Total Reward: 30
# Episode 496: Total Reward: 38
# Episode 497: Total Reward: 38
# Episode 498: Total Reward: 36
# Episode 499: Total Reward: 28
# Episode 500: Total Reward: 44
# Episode 501: Total Reward: 32
# Episode 502: Total Reward: 36
# Episode 503: Total Reward: 40
# Episode 504: Total Reward: 30
# Episode 505: Total Reward: 28
# Episode 506: Total Reward: 34
# Episode 507: Total Reward: 30
# Episode 508: Total Reward: 30
# Episode 509: Total Reward: 14
# Episode 510: Total Reward: 26
# Episode 511: Total Reward: 32
# Episode 512: Total Reward: 34
# Episode 513: Total Reward: 22
# Episode 514: Total Reward: 26
# Episode 515: Total Reward: 30
# Episode 516: Total Reward: 34
# Episode 517: Total Reward: 20
# Episode 518: Total Reward: 36
# Episode 519: Total Reward: 26
# Episode 520: Total Reward: 26
# Episode 521: Total Reward: 26
# Episode 522: Total Reward: 28
# Episode 523: Total Reward: 34
# Episode 524: Total Reward: 26
# Episode 525: Total Reward: 36
# Episode 526: Total Reward: 24
# Episode 527: Total Reward: 34
# Episode 528: Total Reward: 40
# Episode 529: Total Reward: 38
# Episode 530: Total Reward: 36
# Episode 531: Total Reward: 28
# Episode 532: Total Reward: 28
# Episode 533: Total Reward: 34
# Episode 534: Total Reward: 22
# Episode 535: Total Reward: 30
# Episode 536: Total Reward: 32
# Episode 537: Total Reward: 38
# Episode 538: Total Reward: 36
# Episode 539: Total Reward: 28
# Episode 540: Total Reward: 26
# Episode 541: Total Reward: 42
# Episode 542: Total Reward: 32
# Episode 543: Total Reward: 28
# Episode 544: Total Reward: 26
# Episode 545: Total Reward: 34
# Episode 546: Total Reward: 30
# Episode 547: Total Reward: 28
# Episode 548: Total Reward: 20
# Episode 549: Total Reward: 28
# Episode 550: Total Reward: 20
# Episode 551: Total Reward: 20
# Episode 552: Total Reward: 32
# Episode 553: Total Reward: 32
# Episode 554: Total Reward: 36
# Episode 555: Total Reward: 34
# Episode 556: Total Reward: 30
# Episode 557: Total Reward: 16
# Episode 558: Total Reward: 28
# Episode 559: Total Reward: 24
# Episode 560: Total Reward: 34
# Episode 561: Total Reward: 34
# Episode 562: Total Reward: 36
# Episode 563: Total Reward: 36
# Episode 564: Total Reward: 34
# Episode 565: Total Reward: 28
# Episode 566: Total Reward: 30
# Episode 567: Total Reward: 20
# Episode 568: Total Reward: 12
# Episode 569: Total Reward: 38
# Episode 570: Total Reward: 30
# Episode 571: Total Reward: 28
# Episode 572: Total Reward: 30
# Episode 573: Total Reward: 26
# Episode 574: Total Reward: 36
# Episode 575: Total Reward: 30
# Episode 576: Total Reward: 22
# Episode 577: Total Reward: 28
# Episode 578: Total Reward: 20
# Episode 579: Total Reward: 34
# Episode 580: Total Reward: 38
# Episode 581: Total Reward: 32
# Episode 582: Total Reward: 26
# Episode 583: Total Reward: 28
# Episode 584: Total Reward: 34
# Episode 585: Total Reward: 28
# Episode 586: Total Reward: 34
# Episode 587: Total Reward: 28
# Episode 588: Total Reward: 20
# Episode 589: Total Reward: 26
# Episode 590: Total Reward: 34
# Episode 591: Total Reward: 28
# Episode 592: Total Reward: 22
# Episode 593: Total Reward: 32
# Episode 594: Total Reward: 22
# Episode 595: Total Reward: 32
# Episode 596: Total Reward: 26
# Episode 597: Total Reward: 16
# Episode 598: Total Reward: 24
# Episode 599: Total Reward: 18
# Episode 600: Total Reward: 20
# Episode 601: Total Reward: 42
# Episode 602: Total Reward: 30
# Episode 603: Total Reward: 36
# Episode 604: Total Reward: 34
# Episode 605: Total Reward: 36
# Episode 606: Total Reward: 32
# Episode 607: Total Reward: 24
# Episode 608: Total Reward: 42
# Episode 609: Total Reward: 36
# Episode 610: Total Reward: 24
# Episode 611: Total Reward: 36
# Episode 612: Total Reward: 14
# Episode 613: Total Reward: 32
# Episode 614: Total Reward: 28
# Episode 615: Total Reward: 38
# Episode 616: Total Reward: 26
# Episode 617: Total Reward: 30
# Episode 618: Total Reward: 28
# Episode 619: Total Reward: 34
# Episode 620: Total Reward: 28
# Episode 621: Total Reward: 18
# Episode 622: Total Reward: 38
# Episode 623: Total Reward: 28
# Episode 624: Total Reward: 30
# Episode 625: Total Reward: 24
# Episode 626: Total Reward: 38
# Episode 627: Total Reward: 32
# Episode 628: Total Reward: 36
# Episode 629: Total Reward: 38
# Episode 630: Total Reward: 34
# Episode 631: Total Reward: 28
# Episode 632: Total Reward: 34
# Episode 633: Total Reward: 28
# Episode 634: Total Reward: 34
# Episode 635: Total Reward: 26
# Episode 636: Total Reward: 36
# Episode 637: Total Reward: 32
# Episode 638: Total Reward: 34
# Episode 639: Total Reward: 22
# Episode 640: Total Reward: 42
# Episode 641: Total Reward: 32
# Episode 642: Total Reward: 32
# Episode 643: Total Reward: 26
# Episode 644: Total Reward: 24
# Episode 645: Total Reward: 32
# Episode 646: Total Reward: 26
# Episode 647: Total Reward: 22
# Episode 648: Total Reward: 32
# Episode 649: Total Reward: 36
# Episode 650: Total Reward: 20
# Episode 651: Total Reward: 34
# Episode 652: Total Reward: 28
# Episode 653: Total Reward: 30
# Episode 654: Total Reward: 32
# Episode 655: Total Reward: 24
# Episode 656: Total Reward: 34
# Episode 657: Total Reward: 26
# Episode 658: Total Reward: 22
# Episode 659: Total Reward: 30
# Episode 660: Total Reward: 26
# Episode 661: Total Reward: 32
# Episode 662: Total Reward: 30
# Episode 663: Total Reward: 34
# Episode 664: Total Reward: 36
# Episode 665: Total Reward: 30
# Episode 666: Total Reward: 28
# Episode 667: Total Reward: 32
# Episode 668: Total Reward: 26
# Episode 669: Total Reward: 30
# Episode 670: Total Reward: 18
# Episode 671: Total Reward: 34
# Episode 672: Total Reward: 28
# Episode 673: Total Reward: 28
# Episode 674: Total Reward: 34
# Episode 675: Total Reward: 40
# Episode 676: Total Reward: 30
# Episode 677: Total Reward: 20
# Episode 678: Total Reward: 34
# Episode 679: Total Reward: 34
# Episode 680: Total Reward: 24
# Episode 681: Total Reward: 20
# Episode 682: Total Reward: 30
# Episode 683: Total Reward: 32
# Episode 684: Total Reward: 26
# Episode 685: Total Reward: 34
# Episode 686: Total Reward: 34
# Episode 687: Total Reward: 20
# Episode 688: Total Reward: 36
# Episode 689: Total Reward: 40
# Episode 690: Total Reward: 38
# Episode 691: Total Reward: 24
# Episode 692: Total Reward: 26
# Episode 693: Total Reward: 30
# Episode 694: Total Reward: 30
# Episode 695: Total Reward: 36
# Episode 696: Total Reward: 30
# Episode 697: Total Reward: 32
# Episode 698: Total Reward: 26
# Episode 699: Total Reward: 34
# Episode 700: Total Reward: 36
# Episode 701: Total Reward: 20
# Episode 702: Total Reward: 32
# Episode 703: Total Reward: 34
# Episode 704: Total Reward: 32
# Episode 705: Total Reward: 40
# Episode 706: Total Reward: 30
# Episode 707: Total Reward: 30
# Episode 708: Total Reward: 28
# Episode 709: Total Reward: 30
# Episode 710: Total Reward: 30
# Episode 711: Total Reward: 38
# Episode 712: Total Reward: 18
# Episode 713: Total Reward: 22
# Episode 714: Total Reward: 26
# Episode 715: Total Reward: 28
# Episode 716: Total Reward: 32
# Episode 717: Total Reward: 32
# Episode 718: Total Reward: 18
# Episode 719: Total Reward: 28
# Episode 720: Total Reward: 28
# Episode 721: Total Reward: 24
# Episode 722: Total Reward: 24
# Episode 723: Total Reward: 30
# Episode 724: Total Reward: 36
# Episode 725: Total Reward: 28
# Episode 726: Total Reward: 40
# Episode 727: Total Reward: 20
# Episode 728: Total Reward: 32
# Episode 729: Total Reward: 32
# Episode 730: Total Reward: 30
# Episode 731: Total Reward: 30
# Episode 732: Total Reward: 32
# Episode 733: Total Reward: 36
# Episode 734: Total Reward: 40
# Episode 735: Total Reward: 36
# Episode 736: Total Reward: 26
# Episode 737: Total Reward: 36
# Episode 738: Total Reward: 36
# Episode 739: Total Reward: 26
# Episode 740: Total Reward: 34
# Episode 741: Total Reward: 34
# Episode 742: Total Reward: 32
# Episode 743: Total Reward: 20
# Episode 744: Total Reward: 30
# Episode 745: Total Reward: 30
# Episode 746: Total Reward: 22
# Episode 747: Total Reward: 26
# Episode 748: Total Reward: 30
# Episode 749: Total Reward: 28
# Episode 750: Total Reward: 30
# Episode 751: Total Reward: 30
# Episode 752: Total Reward: 36
# Episode 753: Total Reward: 28
# Episode 754: Total Reward: 38
# Episode 755: Total Reward: 28
# Episode 756: Total Reward: 28
# Episode 757: Total Reward: 40
# Episode 758: Total Reward: 26
# Episode 759: Total Reward: 34
# Episode 760: Total Reward: 40
# Episode 761: Total Reward: 34
# Episode 762: Total Reward: 24
# Episode 763: Total Reward: 28
# Episode 764: Total Reward: 30
# Episode 765: Total Reward: 40
# Episode 766: Total Reward: 40
# Episode 767: Total Reward: 24
# Episode 768: Total Reward: 36
# Episode 769: Total Reward: 32
# Episode 770: Total Reward: 24
# Episode 771: Total Reward: 32
# Episode 772: Total Reward: 32
# Episode 773: Total Reward: 22
# Episode 774: Total Reward: 26
# Episode 775: Total Reward: 30
# Episode 776: Total Reward: 32
# Episode 777: Total Reward: 22
# Episode 778: Total Reward: 28
# Episode 779: Total Reward: 36
# Episode 780: Total Reward: 26
# Episode 781: Total Reward: 26
# Episode 782: Total Reward: 26
# Episode 783: Total Reward: 40
# Episode 784: Total Reward: 34
# Episode 785: Total Reward: 38
# Episode 786: Total Reward: 30
# Episode 787: Total Reward: 32
# Episode 788: Total Reward: 36
# Episode 789: Total Reward: 30
# Episode 790: Total Reward: 42
# Episode 791: Total Reward: 28
# Episode 792: Total Reward: 16
# Episode 793: Total Reward: 40
# Episode 794: Total Reward: 30
# Episode 795: Total Reward: 24
# Episode 796: Total Reward: 30
# Episode 797: Total Reward: 42
# Episode 798: Total Reward: 22
# Episode 799: Total Reward: 38
# Episode 800: Total Reward: 34
# Episode 801: Total Reward: 30
# Episode 802: Total Reward: 34
# Episode 803: Total Reward: 34
# Episode 804: Total Reward: 38
# Episode 805: Total Reward: 20
# Episode 806: Total Reward: 24
# Episode 807: Total Reward: 24
# Episode 808: Total Reward: 26
# Episode 809: Total Reward: 32
# Episode 810: Total Reward: 32
# Episode 811: Total Reward: 36
# Episode 812: Total Reward: 34
# Episode 813: Total Reward: 34
# Episode 814: Total Reward: 22
# Episode 815: Total Reward: 38
# Episode 816: Total Reward: 22
# Episode 817: Total Reward: 24
# Episode 818: Total Reward: 22
# Episode 819: Total Reward: 26
# Episode 820: Total Reward: 32
# Episode 821: Total Reward: 30
# Episode 822: Total Reward: 24
# Episode 823: Total Reward: 32
# Episode 824: Total Reward: 34
# Episode 825: Total Reward: 20
# Episode 826: Total Reward: 36
# Episode 827: Total Reward: 28
# Episode 828: Total Reward: 40
# Episode 829: Total Reward: 30
# Episode 830: Total Reward: 34
# Episode 831: Total Reward: 34
# Episode 832: Total Reward: 34
# Episode 833: Total Reward: 38
# Episode 834: Total Reward: 42
# Episode 835: Total Reward: 30
# Episode 836: Total Reward: 26
# Episode 837: Total Reward: 30
# Episode 838: Total Reward: 20
# Episode 839: Total Reward: 40
# Episode 840: Total Reward: 20
# Episode 841: Total Reward: 28
# Episode 842: Total Reward: 32
# Episode 843: Total Reward: 30
# Episode 844: Total Reward: 24
# Episode 845: Total Reward: 22
# Episode 846: Total Reward: 30
# Episode 847: Total Reward: 34
# Episode 848: Total Reward: 30
# Episode 849: Total Reward: 34
# Episode 850: Total Reward: 26
# Episode 851: Total Reward: 20
# Episode 852: Total Reward: 24
# Episode 853: Total Reward: 30
# Episode 854: Total Reward: 24
# Episode 855: Total Reward: 18
# Episode 856: Total Reward: 32
# Episode 857: Total Reward: 38
# Episode 858: Total Reward: 36
# Episode 859: Total Reward: 26
# Episode 860: Total Reward: 28
# Episode 861: Total Reward: 40
# Episode 862: Total Reward: 30
# Episode 863: Total Reward: 32
# Episode 864: Total Reward: 26
# Episode 865: Total Reward: 40
# Episode 866: Total Reward: 34
# Episode 867: Total Reward: 28
# Episode 868: Total Reward: 32
# Episode 869: Total Reward: 32
# Episode 870: Total Reward: 30
# Episode 871: Total Reward: 34
# Episode 872: Total Reward: 38
# Episode 873: Total Reward: 30
# Episode 874: Total Reward: 32
# Episode 875: Total Reward: 28
# Episode 876: Total Reward: 34
# Episode 877: Total Reward: 40
# Episode 878: Total Reward: 36
# Episode 879: Total Reward: 40
# Episode 880: Total Reward: 34
# Episode 881: Total Reward: 38
# Episode 882: Total Reward: 32
# Episode 883: Total Reward: 38
# Episode 884: Total Reward: 30
# Episode 885: Total Reward: 18
# Episode 886: Total Reward: 34
# Episode 887: Total Reward: 36
# Episode 888: Total Reward: 26
# Episode 889: Total Reward: 34
# Episode 890: Total Reward: 28
# Episode 891: Total Reward: 30
# Episode 892: Total Reward: 26
# Episode 893: Total Reward: 30
# Episode 894: Total Reward: 30
# Episode 895: Total Reward: 34
# Episode 896: Total Reward: 36
# Episode 897: Total Reward: 24
# Episode 898: Total Reward: 36
# Episode 899: Total Reward: 28
# Episode 900: Total Reward: 36
# Episode 901: Total Reward: 36
# Episode 902: Total Reward: 40
# Episode 903: Total Reward: 28
# Episode 904: Total Reward: 24
# Episode 905: Total Reward: 18
# Episode 906: Total Reward: 40
# Episode 907: Total Reward: 22
# Episode 908: Total Reward: 16
# Episode 909: Total Reward: 30
# Episode 910: Total Reward: 38
# Episode 911: Total Reward: 32
# Episode 912: Total Reward: 30
# Episode 913: Total Reward: 34
# Episode 914: Total Reward: 34
# Episode 915: Total Reward: 26
# Episode 916: Total Reward: 28
# Episode 917: Total Reward: 32
# Episode 918: Total Reward: 28
# Episode 919: Total Reward: 32
# Episode 920: Total Reward: 30
# Episode 921: Total Reward: 34
# Episode 922: Total Reward: 26
# Episode 923: Total Reward: 28
# Episode 924: Total Reward: 32
# Episode 925: Total Reward: 36
# Episode 926: Total Reward: 30
# Episode 927: Total Reward: 24
# Episode 928: Total Reward: 22
# Episode 929: Total Reward: 30
# Episode 930: Total Reward: 36
# Episode 931: Total Reward: 16
# Episode 932: Total Reward: 32
# Episode 933: Total Reward: 26
# Episode 934: Total Reward: 28
# Episode 935: Total Reward: 36
# Episode 936: Total Reward: 32
# Episode 937: Total Reward: 32
# Episode 938: Total Reward: 28
# Episode 939: Total Reward: 30
# Episode 940: Total Reward: 20
# Episode 941: Total Reward: 34
# Episode 942: Total Reward: 24
# Episode 943: Total Reward: 36
# Episode 944: Total Reward: 30
# Episode 945: Total Reward: 30
# Episode 946: Total Reward: 32
# Episode 947: Total Reward: 38
# Episode 948: Total Reward: 14
# Episode 949: Total Reward: 24
# Episode 950: Total Reward: 36
# Episode 951: Total Reward: 30
# Episode 952: Total Reward: 18
# Episode 953: Total Reward: 24
# Episode 954: Total Reward: 18
# Episode 955: Total Reward: 22
# Episode 956: Total Reward: 28
# Episode 957: Total Reward: 20
# Episode 958: Total Reward: 28
# Episode 959: Total Reward: 28
# Episode 960: Total Reward: 30
# Episode 961: Total Reward: 36
# Episode 962: Total Reward: 30
# Episode 963: Total Reward: 34
# Episode 964: Total Reward: 22
# Episode 965: Total Reward: 26
# Episode 966: Total Reward: 40
# Episode 967: Total Reward: 28
# Episode 968: Total Reward: 30
# Episode 969: Total Reward: 24
# Episode 970: Total Reward: 30
# Episode 971: Total Reward: 24
# Episode 972: Total Reward: 34
# Episode 973: Total Reward: 22
# Episode 974: Total Reward: 32
# Episode 975: Total Reward: 26
# Episode 976: Total Reward: 24
# Episode 977: Total Reward: 20
# Episode 978: Total Reward: 24
# Episode 979: Total Reward: 30
# Episode 980: Total Reward: 32
# Episode 981: Total Reward: 30
# Episode 982: Total Reward: 28
# Episode 983: Total Reward: 18
# Episode 984: Total Reward: 18
# Episode 985: Total Reward: 42
# Episode 986: Total Reward: 26
# Episode 987: Total Reward: 30
# Episode 988: Total Reward: 28
# Episode 989: Total Reward: 34
# Episode 990: Total Reward: 38
# Episode 991: Total Reward: 34
# Episode 992: Total Reward: 40
# Episode 993: Total Reward: 28
# Episode 994: Total Reward: 32
# Episode 995: Total Reward: 30
# Episode 996: Total Reward: 24
# Episode 997: Total Reward: 26
# Episode 998: Total Reward: 36
# Episode 999: Total Reward: 26
# Episode 1000: Total Reward: 32

# %%
from fastapi import FastAPI, HTTPException

app = FastAPI()

@app.post("/recommend-slot/")
def recommend_slot(user_id: int):
    # Placeholder for fetching user state
    user_state = np.random.rand(6)  # Simulated state
    recommended_slot = agent.act(user_state)
    return {"recommended_slot": recommended_slot}

@app.post("/update-slot/")
def update_slot(user_id: int, sender_slot: int, receiver_slot: int = None):
    # Logic to update slots in the database
    final_slot = receiver_slot if receiver_slot is not None else sender_slot
    return {"final_slot": final_slot}

# %%
! uvicorn main:app --reload
# Out:
# ^C

# %%
pip install fastapi uvicorn pymongo torch numpy
# Out:
# Requirement already satisfied: fastapi in c:\users\hp\anaconda3\lib\site-packages (0.115.6)
# Requirement already satisfied: uvicorn in c:\users\hp\anaconda3\lib\site-packages (0.32.1)
# Collecting pymongo
#   Downloading pymongo-4.10.1-cp310-cp310-win_amd64.whl (826 kB)
#      -------------------------------------- 826.8/826.8 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: torch in c:\users\hp\anaconda3\lib\site-packages (1.12.1)
# Requirement already satisfied: numpy in c:\users\hp\anaconda3\lib\site-packages (1.23.5)
# Requirement already satisfied: starlette<0.42.0,>=0.40.0 in c:\users\hp\anaconda3\lib\site-packages (from fastapi) (0.41.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\hp\anaconda3\lib\site-packages (from fastapi) (4.12.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in c:\users\hp\anaconda3\lib\site-packages (from fastapi) (2.10.3)
# Requirement already satisfied: click>=7.0 in c:\users\hp\anaconda3\lib\site-packages (from uvicorn) (8.0.4)
# Requirement already satisfied: h11>=0.8 in c:\users\hp\anaconda3\lib\site-packages (from uvicorn) (0.14.0)
# Collecting dnspython<3.0.0,>=1.16.0
#   Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#      -------------------------------------- 313.6/313.6 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\users\hp\appdata\roaming\python\python310\site-packages (from click>=7.0->uvicorn) (0.4.5)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hp\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\hp\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (2.27.1)
# Requirement already satisfied: anyio<5,>=3.4.0 in c:\users\hp\anaconda3\lib\site-packages (from starlette<0.42.0,>=0.40.0->fastapi) (3.5.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\hp\anaconda3\lib\site-packages (from anyio<5,>=3.4.0->starlette<0.42.0,>=0.40.0->fastapi) (1.2.0)
# Requirement already satisfied: idna>=2.8 in c:\users\hp\anaconda3\lib\site-packages (from anyio<5,>=3.4.0->starlette<0.42.0,>=0.40.0->fastapi) (3.4)
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.7.0 pymongo-4.10.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from fastapi import FastAPI, HTTPException
from pydantic import BaseModel
from pymongo import MongoClient
import numpy as np
import random
import torch
import torch.nn as nn
import torch.optim as optim
from datetime import datetime

# Initialize FastAPI
app = FastAPI()

# MongoDB Configuration
client = MongoClient("mongodb://localhost:27017/")
db = client['delivery_db']
user_collection = db['users']
delivery_logs = db['delivery_logs']

# RL Model
class DQNAgent:
    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.memory = []
        self.model = nn.Sequential(
            nn.Linear(state_size, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, action_size)
        )
        self.optimizer = optim.Adam(self.model.parameters(), lr=0.001)
        self.criterion = nn.MSELoss()

    def act(self, state, epsilon=0.1):
        if np.random.rand() < epsilon:
            return random.randrange(self.action_size)
        state_tensor = torch.FloatTensor(state).unsqueeze(0)
        q_values = self.model(state_tensor)
        return torch.argmax(q_values).item()

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))
        if len(self.memory) > 2000:
            self.memory.pop(0)

    def replay(self, batch_size=32):
        if len(self.memory) < batch_size:
            return
        batch = random.sample(self.memory, batch_size)
        states, actions, rewards, next_states, dones = zip(*batch)

        states = torch.FloatTensor(states)
        actions = torch.LongTensor(actions)
        rewards = torch.FloatTensor(rewards)
        next_states = torch.FloatTensor(next_states)
        dones = torch.FloatTensor(dones)

        q_values = self.model(states).gather(1, actions.unsqueeze(1)).squeeze(1)
        next_q_values = self.model(next_states).max(1)[0]
        expected_q_values = rewards + (0.99 * next_q_values * (1 - dones))

        loss = self.criterion(q_values, expected_q_values.detach())
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()


# Initialize RL Agent
state_size = 6  # Example state size
action_size = 6  # Number of time slots
agent = DQNAgent(state_size, action_size)


# Helper Functions
def get_user_state(user_id):
    user_data = user_collection.find_one({"user_id": user_id})
    if not user_data:
        raise ValueError("User not found")
    return np.array([
        user_data.get('success_rate_slot_1', 0.5),
        user_data.get('success_rate_slot_2', 0.5),
        user_data.get('success_rate_slot_3', 0.5),
        user_data.get('failure_rate_slot_4', 0.5),
        user_data.get('holiday_indicator', 0),
        user_data.get('day_of_week', 0)
    ])


def log_delivery(user_id, slot, success):
    delivery_logs.insert_one({
        "user_id": user_id,
        "slot": slot,
        "success": success,
        "timestamp": datetime.utcnow()
    })


def update_user_stats(user_id, slot, success):
    user_data = user_collection.find_one({"user_id": user_id}) or {"user_id": user_id}
    key = f"success_rate_slot_{slot + 1}"
    if success:
        user_data[key] = user_data.get(key, 0.5) * 0.9 + 0.1
    else:
        user_data[key] = user_data.get(key, 0.5) * 0.9
    user_collection.update_one({"user_id": user_id}, {"$set": user_data}, upsert=True)


# API Models
class RecommendSlotRequest(BaseModel):
    user_id: int


class UpdateSlotRequest(BaseModel):
    user_id: int
    slot: int
    success: bool


# API Endpoints
@app.post("/recommend-slot/")
def recommend_slot(request: RecommendSlotRequest):
    try:
        user_state = get_user_state(request.user_id)
        recommended_slot = agent.act(user_state)
        return {"recommended_slot": recommended_slot}
    except ValueError as e:
        raise HTTPException(status_code=404, detail=str(e))


@app.post("/update-slot/")
def update_slot(request: UpdateSlotRequest):
    log_delivery(request.user_id, request.slot, request.success)
    update_user_stats(request.user_id, request.slot, request.success)
    return {"message": "Slot and user stats updated successfully"}

# %%
from pymongo import MongoClient

# MongoDB Connection URL
MONGO_URL = "mongodb+srv://slotmatesih2024:1lcUSUznPr0b1Nf3@cluster0.rqzix.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# Initialize the MongoDB Client
client = MongoClient(MONGO_URL)

# Access the Database
db = client["slotmates"]  # Replace 'slotmates' with your database name
collection = db["delivery_slots"]  # Replace 'delivery_slots' with your collection name

# %%
# Inserting dummy data
dummy_data = [
    {
        "user_id": 123,
        "mobile_number": "9876543210",
        "predicted_slot": "10:00 AM - 12:00 PM",
        "user_provided_slot": "2:00 PM - 4:00 PM",
        "delivery_status": "success",  # success or failed
        "date": "2024-12-08",
        "is_holiday": False
    },
    {
        "user_id": 456,
        "mobile_number": "9876543222",
        "predicted_slot": "2:00 PM - 4:00 PM",
        "user_provided_slot": "10:00 AM - 12:00 PM",
        "delivery_status": "failed",  # success or failed
        "date": "2024-12-08",
        "is_holiday": True
    }
]

# Insert the dummy data into MongoDB
collection.insert_many(dummy_data)
print("Dummy data inserted successfully!")
# Out:
# Dummy data inserted successfully!

# %%
! uvicorn script_name:app --reload
# Out:
# ^C
